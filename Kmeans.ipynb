# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
from sklearn.cluster import KMeans

# %%
import csv
df=pd.read_csv('incomewithlocation_alldata.csv', engine="python", delimiter =',')

# %%
#print(df)
df.iloc[:,:]
# Out:
#      country  location  incomebracket  epiranking    epi  envirohealth  \
# 0          1         2            0.0         168  37.74         36.76
# 1          2         3            2.0          40  65.46         65.67
# 2          3         0            2.0          88  57.18         80.95
# 3          4         0            1.0         170  37.44         33.79
# 4          5         1            3.0          76  59.18         76.53
# ..       ...       ...            ...         ...    ...           ...
# 175      175         5            1.0         144  44.55         50.46
# 176      176         1            2.0          51  63.89         75.74
# 177      177         2            1.0         132  46.96         47.12
# 178      178         0            1.0         117  50.97         31.57
# 179      179         0            1.0         149  43.41         40.58
#
#      ecosystemviability
# 0                 38.40
# 1                 65.32
# 2                 41.34
# ...

# %%
#df.iloc[:,1]
#leave a comment for yourself to know exactly what you did
#x=environmental health
#y=epi
#color by location
envirohealth = df.iloc[:,5]
epi = df.iloc[:,4]
ecosystemviability = df.iloc[:,6]
incomebracket = df.iloc[:,2]
location = df.iloc[:,1]

# %% [markdown]
# ## EPI and Envirohealth (income)

# %%
plt.scatter(df.iloc[:,5],df.iloc[:,4],c=incomebracket)

# %%
kmeans= KMeans(n_clusters=6, init='k-means++', max_iter=300, n_init=10, random_state=0)
envirohealth_np = envirohealth.to_numpy()
epi_np = epi.to_numpy()
X = np.column_stack((envirohealth, epi))
pred_y = kmeans.fit_predict(X)
plt.scatter(X[:,0], X[:,1], c=pred_y)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s=300, c='red')

# %% [markdown]
# ## EPI and Ecosystem vitality (location)

# %%
plt.scatter(df.iloc[:,6],df.iloc[:,4],c=location)

# %%
kmeans= KMeans(n_clusters=6, init='k-means++', max_iter=300, n_init=10, random_state=0)
ecosystemviability_np = ecosystemviability.to_numpy()
epi_np = epi.to_numpy()
#pred_y = kmeans.fit_predict(ecosystemviability)

# %%
X = np.column_stack((ecosystemviability, epi))

# %%
pred_y = kmeans.fit_predict(X)

# %%
plt.scatter(X[:,0], X[:,1], c=pred_y)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s=300, c='red')

# %% [markdown]
# ## EPI and Environmental Healh (location)

# %%
plt.scatter(df.iloc[:,5],df.iloc[:,4],c=location)

# %% [markdown]
# #### kmeans= KMeans(n_clusters=6, init='k-means++', max_iter=300, n_init=10, random_state=0)
# envirohealth_np = envirohealth.to_numpy()
# epi_np = epi.to_numpy()
# X = np.column_stack((envirohealth, epi))
# pred_y = kmeans.fit_predict(X)
# plt.scatter(X[:,0], X[:,1], c=pred_y)
# plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s=300, c='red')

# %% [markdown]
# ## EPI and Ecosystem Vitality (income)

# %%
plt.scatter(df.iloc[:,6],df.iloc[:,4],c=incomebracket)

# %% [markdown]
# kmeans= KMeans(n_clusters=4, init='k-means++', max_iter=300, n_init=10, random_state=0)
# ecosystemviability_np = ecosystemviability.to_numpy()
# epi_np = epi.to_numpy()
# X = np.column_stack((ecosystemviability, epi))
# pred_y = kmeans.fit_predict(X)
# plt.scatter(X[:,0], X[:,1], c=pred_y)
# plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s=300, c='red')

# %% [markdown]
# ## Ecosystem Vitality and Envirohealth (Location)

# %%
plt.scatter(df.iloc[:,6],df.iloc[:,5],c=location)

# %%
kmeans= KMeans(n_clusters=6, init='k-means++', max_iter=300, n_init=10, random_state=0)
ecosystemviability_np = ecosystemviability.to_numpy()
envirohealth_np = envirohealth.to_numpy()
X = np.column_stack((ecosystemviability, envirohealth))
pred_y = kmeans.fit_predict(X)
plt.scatter(X[:,0], X[:,1], c=pred_y)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s=300, c='red')

# %% [markdown]
# ## Envirohealth and Ecosystem Vitality (income)

# %%
plt.scatter(df.iloc[:,6],df.iloc[:,5],c=incomebracket)

# %%
kmeans= KMeans(n_clusters=4, init='k-means++', max_iter=300, n_init=10, random_state=0)
ecosystemviability_np = ecosystemviability.to_numpy()
envirohealth_np = envirohealth.to_numpy()
X = np.column_stack((ecosystemviability, envirohealth))
pred_y = kmeans.fit_predict(X)
plt.scatter(X[:,0], X[:,1], c=pred_y)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s=300, c='red')
